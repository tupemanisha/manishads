# %% [markdown]
# **Practical 3**
#
# Descriptive Statistics - Measures of Central Tendency and variability Perform the following operations on
# any open source dataset (e.g., data.csv)
#
# 1. Provide summary statistics (mean, median, minimum, maximum, standard deviation) for a dataset
# (age, income etc.) with numeric variables grouped by one of the qualitative (categorical) variable. For
# example, if your categorical variable is age groups and quantitative variable is income, then provide
# summary statistics of income grouped by the age groups. Create a list that contains a numeric value for
# each response to the categorical variable.
#
# 2. Write a Python program to display some basic statistical details like percentile, mean, standard
# deviation etc. of the species of ‘Iris-setosa’, ‘Iris-versicolor’ and ‘Iris- versicolor’ of iris.csv dataset.
# Provide the codes with outputs and explain everything that you do in this step.

# %%
# 1. Import all required python libraries
import pandas as pd
import warnings
warnings.filterwarnings('ignore')

# %%
#2. Load datset in g drive
df=pd.read_csv('/content/DSBDA pract-3(dataset)Mall_Customers.csv')
print(df)
# Out:
#      CustomerID   Genre   Age Group  Age  Annual Income (k$)  \
# 0             1    Male        Teen   19                  15
# 1             2    Male  Middle Age   21                  15
# 2             3  Female  Middle Age   20                  16
# 3             4  Female  Middle Age   23                  16
# 4             5  Female  Middle Age   31                  17
# ..          ...     ...         ...  ...                 ...
# 195         196  Female  Middle Age   35                 120
# 196         197  Female       Elder   45                 126
# 197         198    Male  Middle Age   32                 126
# 198         199    Male  Middle Age   32                 137
# 199         200    Male  Middle Age   30                 137
#
#      Spending Score (1-100)
# 0                        39
# 1                        81
# 2                         6
# 3                        77
# 4                        40
# ..                      ...
# ...

# %% [markdown]
# Q1. Provide summary statistics (mean, median, minimum, maximum, standard deviation) for a dataset
# (age, income etc.) with numeric variables grouped by one of the qualitative (categorical) variable. For
# example, if your categorical variable is age groups and quantitative variable is income, then provide
# summary statistics of income grouped by the age groups. Create a list that contains a numeric value for
# each response to the categorical variable.

# %%
df.shape
# Out:
# (200, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 6 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   CustomerID              200 non-null    int64
#  1   Genre                   200 non-null    object
#  2   Age Group               200 non-null    object
#  3   Age                     200 non-null    int64
#  4   Annual Income (k$)      200 non-null    int64
#  5   Spending Score (1-100)  200 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 9.5+ KB

# %%
df.isnull().sum()
# Out:
# CustomerID                0
# Genre                     0
# Age Group                 0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %%
df1=df.copy()

# %%
# delete CustomerID from data frame
df.drop(["CustomerID"], axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-9-0896040ad05e> in <cell line: 2>()
#       1 # delete CustomerID from data frame
# ----> 2 df.drop(["CustomerID"], axis=1,inplace=True)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# ...

# %%
df
# Out:
#       Genre   Age Group  Age  Annual Income (k$)  Spending Score (1-100)
# 0      Male        Teen   19                  15                      39
# 1      Male  Middle Age   21                  15                      81
# 2    Female  Middle Age   20                  16                       6
# 3    Female  Middle Age   23                  16                      77
# 4    Female  Middle Age   31                  17                      40
# ..      ...         ...  ...                 ...                     ...
# 195  Female  Middle Age   35                 120                      79
# 196  Female       Elder   45                 126                      28
# 197    Male  Middle Age   32                 126                      74
# 198    Male  Middle Age   32                 137                      18
# 199    Male  Middle Age   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df.mean()
# Out:
# Age                       38.85
# Annual Income (k$)        60.56
# Spending Score (1-100)    50.20
# dtype: float64

# %%
#It is also possible to calculate the mean of a particular variable in a data, as show
# where we calculate the mean of the variables 'Age' and 'Income'.
print(df.loc[:,'Age'].mean())
# Out:
# 38.85

# %%
print(df.loc[:,'Annual Income (k$)'].mean())
# Out:
# 60.56

# %% [markdown]
# **Median** In simple terms, median represents the 50th percentile, or the middle value of the data, that
# separates the distribution into two halves. The line of code below prints the median of the numerical
# variables in the data. The command df.median(axis = 0) will also give the same output.

# %%
df.median()
# Out:
# Age                       36.0
# Annual Income (k$)        61.5
# Spending Score (1-100)    50.0
# dtype: float64

# %%
#to calculate a median of a particular column
print(df.loc[:,'Age'].median())
print(df.loc[:,'Annual Income (k$)'].median())
# Out:
# 36.0
# 61.5

# %%
#OR
df[["Age", "Annual Income (k$)"]].median()
# Out:
# Age                   36.0
# Annual Income (k$)    61.5
# dtype: float64

# %% [markdown]
# **Mode** Mode represents the most frequent value of a variable in the data. This is the only central
# tendency measure that can be used with categorical variables, unlike the mean and the median which
# can be used only with quantitative data.

# %%
df.mode()
# Out:
#     Genre   Age Group   Age  Annual Income (k$)  Spending Score (1-100)
# 0  Female  Middle Age  32.0                  54                    42.0
# 1     NaN         NaN   NaN                  78                     NaN

# %%
#OR
df.mode(axis = 0)
# Out:
#     Genre   Age Group   Age  Annual Income (k$)  Spending Score (1-100)
# 0  Female  Middle Age  32.0                  54                    42.0
# 1     NaN         NaN   NaN                  78                     NaN

# %% [markdown]
# **Measures of Dispersion** In the previous sections, we have discussed the various measures of central
# tendency. However, as we have seen in the data, the values of these measures differ for many variables.
#
# This is because of the extent to which a distribution is stretched or squeezed. In statistics, this is
# measured by dispersion which is also referred to as variability, scatter, or spread. The most popular
# measures of dispersion are standard deviation, variance, and the interquartile range.
#
# Standard Deviation Standard deviation is a measure that is used to quantify the amount of variation of a
# set of data values from its mean. A low standard deviation for a variable indicates that the data points
# tend to be close to its mean, and vice versa.

# %%
df.std()
# Out:
# Age                       13.969007
# Annual Income (k$)        26.264721
# Spending Score (1-100)    25.823522
# dtype: float64

# %%
print(df.loc[:,'Age'].std())
print(df.loc[:,'Annual Income (k$)'].std())
# Out:
# 13.96900733155888
# 26.264721165271244

# %%
#calculate the standard deviation of the first five rows
df.std(axis = 1)[0:5]
# Out:
# 0    12.858201
# 1    36.496575
# 2     7.211103
# 3    33.381632
# 4    11.590226
# dtype: float64

# %% [markdown]
# **Variance** Variance is another measure of dispersion. It is the square of the standard deviation and the
# covariance of the random variable with itself. The line of code below prints the variance of all the
# numerical variables in the dataset. The interpretation of the variance is similar to that of the standard
# deviation.

# %%
df.var()
# Out:
# Age                       195.133166
# Annual Income (k$)        689.835578
# Spending Score (1-100)    666.854271
# dtype: float64

# %% [markdown]
# **Interquartile Range (IQR)** The Interquartile Range (IQR) is a measure of statistical dispersion, and is
# calculated as the difference between the upper quartile (75th percentile) and the lower quartile (25th
# percentile). The IQR is also a very important measure for identifying outliers and could be visualized
# using a boxplot.
# IQR can be calculated using the iqr() function. The first line of code below imports the 'iqr' function from
# the scipy.stats module, while the second line prints the IQR for the variable 'Age'.

# %%
from scipy.stats import iqr
iqr(df['Age'])
# Out:
# 20.25

# %% [markdown]
# **Skewness**:
# Another useful statistic is skewness, which is the measure of the symmetry, or lack of it, for a real-valued
# random variable about its mean. The skewness value can be positive, negative, or undefined.
#  In a
# perfectly symmetrical distribution, the mean, the median, and the mode will all have the same value.
#
# However, the variables in our data are not symmetrical, resulting in different values of the central
# tendency.
#
# The skewness values can be interpreted in the following manner:
# Highly skewed distribution: If the skewness value is less than −1 or greater than +1.
#
# Moderately skewed distribution: If the skewness value is between −1 and −½ or between +½ and +1.
#
# Approximately symmetric distribution: If the skewness value is between −½ and +½.
#
# We can calculate the skewness of the numerical variables using the skew() function, as shown **below**

# %%
print(df.skew())
# Out:
# Age                       0.485569
# Annual Income (k$)        0.321843
# Spending Score (1-100)   -0.047220
# dtype: float64

# %% [markdown]
# **Putting Everything Together** We have learned the measures of central tendency and dispersion, in the
# previous sections.
# It is important to analyse these individually, however, because there are certain useful
# functions in python that can be called upon to find these values.
# One such important function is the
#
# .describe() function that prints the summary statistic of the numerical variables.

# %%
df.describe()
# Out:
#               Age  Annual Income (k$)  Spending Score (1-100)
# count  200.000000          200.000000              200.000000
# mean    38.850000           60.560000               50.200000
# std     13.969007           26.264721               25.823522
# min     18.000000           15.000000                1.000000
# 25%     28.750000           41.500000               34.750000
# 50%     36.000000           61.500000               50.000000
# 75%     49.000000           78.000000               73.000000
# max     70.000000          137.000000               99.000000

# %%
df.describe(include='all')
# Out:
#          Genre   Age Group         Age  Annual Income (k$)  \
# count      200         200  200.000000          200.000000
# unique       2           3         NaN                 NaN
# top     Female  Middle Age         NaN                 NaN
# freq       112         104         NaN                 NaN
# mean       NaN         NaN   38.850000           60.560000
# std        NaN         NaN   13.969007           26.264721
# min        NaN         NaN   18.000000           15.000000
# 25%        NaN         NaN   28.750000           41.500000
# 50%        NaN         NaN   36.000000           61.500000
# 75%        NaN         NaN   49.000000           78.000000
# max        NaN         NaN   70.000000          137.000000
#
#         Spending Score (1-100)
# count               200.000000
# unique                     NaN
# top                        NaN
# freq                       NaN
# mean                 50.200000
# std                  25.823522
# ...

# %% [markdown]
# **#Que: Provide summary statistics of income grouped by age group**

# %%
df2=df.groupby(['Genre', 'Age Group'])
df2.first()
# Out:
#                    Age  Annual Income (k$)  Spending Score (1-100)
# Genre  Age Group
# Female Elder        58                  20                      15
#        Middle Age   20                  16                       6
#        Teen         19                  63                      54
# Male   Elder        64                  19                       3
#        Middle Age   21                  15                      81
#        Teen         19                  15                      39

# %%
# grouping income as per the age groups and calculating its mean,median and mode value
df3=df.groupby(['Age Group', 'Annual Income (k$)']).mean()
df3
# Out:
#                                Age  Spending Score (1-100)
# Age Group Annual Income (k$)
# Elder     19                  65.5                     8.5
#           20                  58.0                    15.0
#           23                  52.0                    29.0
#           25                  46.0                     5.0
#           28                  49.5                    23.0
# ...                            ...                     ...
# Teen      63                  19.0                    54.0
#           64                  19.0                    46.0
#           65                  18.5                    49.0
#           74                  19.0                    10.0
#           81                  19.0                     5.0
#
# [115 rows x 2 columns]

# %%
df4=df.groupby(['Age Group', 'Annual Income (k$)']).median()
df4
# Out:
#                                Age  Spending Score (1-100)
# Age Group Annual Income (k$)
# Elder     19                  65.5                     8.5
#           20                  58.0                    15.0
#           23                  52.0                    29.0
#           25                  46.0                     5.0
#           28                  49.5                    23.0
# ...                            ...                     ...
# Teen      63                  19.0                    54.0
#           64                  19.0                    46.0
#           65                  18.5                    49.0
#           74                  19.0                    10.0
#           81                  19.0                     5.0
#
# [115 rows x 2 columns]

# %%
#how to find the mode using pandas groupby
df.groupby(['Age Group','Annual Income (k$)']).agg(lambda x:x.value_counts().index[0])
#value_counts().index[0] gives you the most frequent value in the Series based on the
#If you want to access the actual value associated with this index, you can use total_
# Out:
#                                Genre  Age  Spending Score (1-100)
# Age Group Annual Income (k$)
# Elder     19                    Male   64                       3
#           20                  Female   58                      15
#           23                    Male   52                      29
#           25                  Female   46                       5
#           28                  Female   54                      14
# ...                              ...  ...                     ...
# Teen      63                  Female   19                      54
#           64                    Male   19                      46
#           65                  Female   18                      48
#           74                    Male   19                      10
#           81                    Male   19                       5
#
# [115 rows x 3 columns]

# %%
#List that contains a numeric value for each responce to the categorical value
df5=df.groupby(['Age Group', 'Age', 'Annual Income (k$)'])
df5.first()
# Out:
#                                    Genre  Spending Score (1-100)
# Age Group Age Annual Income (k$)
# Elder     40  29                  Female                      31
#               54                    Male                      48
#               60                  Female                      40
#               69                  Female                      58
#               71                    Male                      95
# ...                                  ...                     ...
# Teen      19  63                  Female                      54
#               64                    Male                      46
#               65                  Female                      50
#               74                    Male                      10
#               81                    Male                       5
#
# [192 rows x 2 columns]
